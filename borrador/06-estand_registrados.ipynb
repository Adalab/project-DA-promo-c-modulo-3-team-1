# %% [markdown]
# ### Estandarizamos los datos

# %%
import pandas as pd
import numpy as np
import sidetable
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import math 
from sklearn.preprocessing import MinMaxScaler
import warnings
from sklearn.preprocessing import RobustScaler
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

# %%
df= pd.read_csv('../datos/registrados/05-registrados_encoding.csv',index_col = 0)

# %%
df.dtypes
# Out:
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# weathersit      int64
# atemp         float64
# hum           float64
# windspeed     float64
# registered      int64
# dtype: object

# %%
numericas = df.select_dtypes(include=np.number)
numericas.head(2)
# Out:
#    season  yr  mnth  holiday  weekday  weathersit     atemp      hum  \
# 0       0   0     1        0        0           1  18.18125  80.5833
# 1       0   0     1        1        1           1  17.68695  69.6087
#
#    windspeed  registered
# 0  10.749882         654
# 1  16.652113         670

# %%
robust = RobustScaler()

# %%
robust.fit(numericas)
# Out:
# RobustScaler()

# %%
X_robust = robust.transform(numericas)

# %%
numericas_robust = pd.DataFrame(X_robust, columns = numericas.columns)
numericas_robust.head(2)
# Out:
#    season   yr  mnth  holiday   weekday  weathersit     atemp       hum  \
# 0    -1.0 -0.5  -1.0     -1.0 -0.666667        -1.0 -0.456399  0.855582
# 1    -1.0 -0.5  -1.0      0.0 -0.333333        -1.0 -0.492863  0.332722
#
#    windspeed  registered
# 0  -0.208909   -1.319816
# 1   0.687550   -1.312801

# %%
numericas_robust.drop(['season','holiday','weekday','weathersit','registered'],axis =1,inplace = True)

# %%
df.drop(['atemp','hum','windspeed'],axis = 1,inplace=True)

# %%
numericas_robust.to_csv('../datos/numer_robust.csv')

# %%
df_total = pd.concat([numericas_robust,df], axis = 1)

# %%
df_total.head(2)
# Out:
#     yr  mnth     atemp       hum  windspeed      dteday  season  yr  mnth  \
# 0 -0.5  -1.0 -0.456399  0.855582  -0.208909  2018-01-01       0   0     1
# 1 -0.5  -1.0 -0.492863  0.332722   0.687550  2018-01-02       0   0     1
#
#    holiday  weekday  weathersit  registered
# 0        0        0           1         654
# 1        1        1           1         670

# %%
df_total.to_csv('../datos/registrados/06-registrados-cod_est.csv')

# %%
df_total.to_pickle('../datos/registrados/06-registrados-cod_est.pickle')
